# %% [markdown]
# ### Analizando resultados parámetros por pareja

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re
sns.set()

# %%
data = pd.read_csv('./data/output0.csv')
data.head(2)
# Out:
#    index       Dyad  Round  Player   Answer  Time  a11  a12  a13  a14  ...  \
# 0      0  822492820      1    8224   Absent     5    0    0    0    0  ...
# 1      0  822492820      2    8224  Present    13    0    0    0    0  ...
#
#    Consistency  Total_visited_dyad  Dif_consist  DLIndex  Similarity  \
# 0          NaN                  32          NaN  0.46875           5
# 1          0.0                  38     0.326087  0.50000          12
#
#    Score_LAG1  Norm_Score_LAG1  Consistency_LEAD1  Dif_consist_LAG1  \
# 0         NaN              NaN           0.000000               NaN
# 1        30.0           0.9875           0.916667               NaN
#
#    Similarity_LAG1
# 0              NaN
# 1              5.0
#
# [2 rows x 91 columns]

# %%
aux = data.groupby(['Round'])['DLIndex'].mean().reset_index()
fig, axes = plt.subplots(1, 2, figsize=(8,4))
sns.lineplot(x='Round', y='DLIndex', data=aux, ax=axes[0])
sns.distplot(data['DLIndex'], ax=axes[1], hist=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,5))
ax = sns.countplot('Category', data=data)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-741cf241a582> in <module>
#       1 fig, ax = plt.subplots(figsize=(8,5))
# ----> 2 ax = sns.countplot('Category', data=data)
#       3 plt.show()
#
# /usr/local/lib/python3.8/site-packages/seaborn/categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3547         raise TypeError("Must pass values for either `x` or `y`")
#    3548
# -> 3549     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3550                           estimator, ci, n_boot, units, seed,
#    3551                           orient, color, palette, saturation,
#
# /usr/local/lib/python3.8/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1602         self.establish_variables(x, y, hue, data, orient,
#    1603                                  order, hue_order, units)
# -> 1604         self.establish_colors(color, palette, saturation)
#    1605         self.estimate_statistic(estimator, ci, n_boot, seed)
#    1606
#
# /usr/local/lib/python3.8/site-packages/seaborn/categorical.py in establish_colors(self, color, palette, saturation)
#     314         # Determine the gray color to use for the lines framing the plot
#     315         light_vals = [colorsys.rgb_to_hls(*c)[1] for c in rgb_colors]
# --> 316         lum = min(light_vals) * .6
#     317         gray = mpl.colors.rgb2hex((lum, lum, lum))
#     318
#
# ValueError: min() arg is an empty sequence

# %%
from FRA import FRASim

cols = ['a' + str(i+1) + str(j+1) for i in range(8) for j in range(8)]

for dyad, grp in df.groupby(['Dyad', 'Round']):
    players = grp.Player.unique()
    pl1 = grp[grp['Player']==players[0]]
    pl2 = grp[grp['Player']==players[1]]
    region1 = pl1[cols].apply(lambda x: list(x), axis=1)
    region2 = pl2[cols].apply(lambda x: list(x), axis=1)
    overlap = np.multiply(region1, region2)
    print(overlap)

#df['overlap'] = df.apply(lambda x: find_overlap(x), axis=1)

# %%
fig = plt.figure(figsize=(15,8))
split = df_fitted['DL'].unique()
for i, sp in enumerate(split):
    df = df_fitted[df_fitted['DL']==sp].sort_values(by='Model')
    plt.subplot(2,4,i+1)
    ax = sns.stripplot(x='Model', y='dev', data=df)
    ax.set_ylim([-5,120])
    plt.xlabel('Model')
    plt.ylabel('dev')
    plt.title(sp)
plt.show()

# %%
df_MB['overlap_med'] = df_MB.Joint > 16
df_MB['overlap_med'] = np.where(df_MB.Joint == False, '<16', '>16')
sns.lmplot(x='Round', y='DLIndex', 
           hue='overlap_med', data=df_MB,
          ci=None, size=5)
# Out:
# /usr/local/lib/python3.7/site-packages/seaborn/regression.py:573: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
df_FR['overlap_med'] = df_FR.Joint > 16
df_FR['overlap_med'] = np.where(df_FR.Joint == False, '<16', '>16')
sns.lmplot(x='Round', y='DLIndex', 
           hue='overlap_med', data=df_FR,
          ci=None, size=5)
# Out:
# /usr/local/lib/python3.7/site-packages/seaborn/regression.py:573: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
